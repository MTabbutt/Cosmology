# %%
# Working on 2015 laptop: Need to be in CCL conda environment to work on CAMB
import camb
import numpy as np
import pandas as pd
import sqlite3
import scipy as sp
import scipy.integrate
from scipy import interpolate
from scipy.interpolate import InterpolatedUnivariateSpline
import matplotlib.pyplot as plt
from camb import model, initialpower

# %%
DATA_PATH = '/Users/megantabbutt/CosmologyDataProducts/'

# %%
# Define Cosmology:

Omega_m = .3089
Omega_k = 0
Omega_L = .6911
hubble_0 = 67.74 # km/sec/Mpc
c = 3.0*(10**5) # km/sec

bias_gal = 1.0
bias_Sne = 1.0

ombh2=0.0225
omch2=0.1188
ns=.96

h = hubble_0 / 100.0

# %%
# pull in panStarrs Auto corr data to compare at end:

PanSTARRS_Data = pd.read_csv(DATA_PATH + 'PanSTARRS_AutoCorr_Plot_Results_df_100000000.csv', index_col=0)
PanSTARRS_Data.head(3)
# Out:
#    r_PanSTARRS_Full  xi_PanSTARRS_Full  varxi_PanSTARRS_Full  \
# 0          0.011772          -0.255842              0.870198
# 1          0.014255           1.896707              0.589932
# 2          0.016538          -0.306261              0.400361
#
#    sig_PanSTARRS_Full
# 0            0.932844
# 1            0.768070
# 2            0.632740

# %% [markdown]
# ## 1. Define terms in integrands

# %% [markdown]
# ***

# %% [markdown]
# ### $n(z)$

# %%
# Pull in the data and make into pandas dataframe 

qry_PanSTARRS_Data_All = "SELECT ID, DEC, RA, zSN, zHost FROM PanSTARRSNEW WHERE (zSN > -999) || (zHost > -999)"

connPAN = sqlite3.connect(DATA_PATH + 'PanSTARRS.db')
PanSTARRSNEW_GoodZ = pd.read_sql(qry_PanSTARRS_Data_All, con=connPAN)
connPAN.close()
PanSTARRSNEW_GoodZ.head(3) # 1129 objects over 10 pointings
# Out:
#           ID       DEC        RA    zSN  zHost
# 0  ps0909006  1.184831  333.9500  0.284 -999.0
# 1  ps0909010 -4.078911   37.1182  0.270 -999.0
# 2  ps0910017 -5.023289   35.2775  0.320 -999.0

# %%
# Make a new column of "zBest" to use in the interpolation of n(z)

# Note: Take the redshift of the supernova if both are given. 
#       If redshift of supernova is unknown, take the redshift of the host. 

zBest = []
for i in PanSTARRSNEW_GoodZ.iterrows(): #.iterrows() returns a tuple (immutable object)
    if i[1]['zSN'] >= 0:
        zBest.append(i[1]['zSN'])
    else:
        zBest.append(i[1]['zHost'])
        
if PanSTARRSNEW_GoodZ.shape[0] == len(zBest):
    PanSTARRSNEW_GoodZ['zBest'] = zBest
    
PanSTARRSNEW_GoodZ.head(3)
# Out:
#           ID       DEC        RA    zSN  zHost  zBest
# 0  ps0909006  1.184831  333.9500  0.284 -999.0  0.284
# 1  ps0909010 -4.078911   37.1182  0.270 -999.0  0.270
# 2  ps0910017 -5.023289   35.2775  0.320 -999.0  0.320

# %% [markdown]
#  Want a number/redshift but normalized still so that its 1 across all bins?

# %%
# Make a histogram to be interpolated

bin_num = 20
bin_width = (PanSTARRSNEW_GoodZ['zBest'].max() - PanSTARRSNEW_GoodZ['zBest'].min())/bin_num

Sne_z_all_hist = np.histogram(PanSTARRSNEW_GoodZ['zBest'], bins=bin_num)
#print(Sne_z_all_hist)

Sne_z_all_bin_centers = 0.5 * (Sne_z_all_hist[1][1:]+ Sne_z_all_hist[1][:-1])

#Sne_z_all_hist_norm = Sne_z_all_hist[0] / sum(Sne_z_all_hist[0]) * bin_num
#Sne_z_all_hist_norm = Sne_z_all_hist[0] / sum(Sne_z_all_hist[0])

Sne_z_all_hist_norm = Sne_z_all_hist[0] / sum(Sne_z_all_hist[0]) / bin_width

redshift_min = PanSTARRSNEW_GoodZ['zBest'].min()
redshift_max = PanSTARRSNEW_GoodZ['zBest'].max()

print("Min redshift = " + str(redshift_min) + "          " + "Max redshift = " + str(redshift_max))
# Out:
# Min redshift = 0.025          Max redshift = 0.9405700000000001

# %%
Sne_z_all_hist_norm
# Out:
# array([0.154787  , 0.40631588, 0.79328338, 1.21894764, 2.28310827,
#        2.20571477, 3.79228153, 2.82486277, 2.43789527, 1.76070214,
#        1.79939889, 0.77393501, 0.87067688, 0.2321805 , 0.17413538,
#        0.09674188, 0.        , 0.        , 0.        , 0.01934838])

# %%
# interpolate:

n_sne_interpolated = interpolate.interp1d(Sne_z_all_bin_centers, Sne_z_all_hist_norm, kind='cubic', bounds_error=False,
                                          fill_value=0.0)

# %%
n_sne_interpolated(.94)
# Out:
# array(0.)

# %%
# Plot the histogram, input points and interpolation for comparison

z_values = np.linspace((Sne_z_all_bin_centers.min()), (Sne_z_all_bin_centers.max()), num=bin_num)

plt.figure(figsize=[16, 8])
plt.bar(Sne_z_all_bin_centers, Sne_z_all_hist_norm, label="Histogram", alpha=.5, color="#fac205", width=.005)
plt.plot(Sne_z_all_bin_centers, Sne_z_all_hist_norm, label="Histogram Binned", c="#0652ff", ls="--")
plt.plot(z_values, n_sne_interpolated(z_values), label="Interpolation", c="#8c000f", alpha=.7, lw=2)
plt.xlabel("Redshift")
plt.ylabel("Count")
plt.legend()
plt.show()

# %%
z_values = np.linspace(0, 1, num=1000000)

plt.figure(figsize=[16, 8])
plt.plot(z_values, n_sne_interpolated(z_values), label="Interpolation", c="#8c000f", alpha=.7, lw=2)
plt.xlabel("Redshift")
plt.show()

# %%
scipy.integrate.quad(n_sne_interpolated, 0, 1, epsrel=10**-12, epsabs=10**-12, limit=5000)
# Out:
# (0.9957766778191214, 3.5937919307116317e-13)

# %% [markdown]
# ***

# %% [markdown]
# ### $\chi(z)$
#
# chi_z_func(z_input) - returns tuple with first element value and second element error for integral

# %% [markdown]
# ### Notes:
#
# - The comoving distance, redshift and derivatives all seem fine when comparing to cosmo-calculator and looking at derivative by eye

# %%
# Need to get a list of zBest that is only unique entries:

zBest_unique = []
for i in zBest:
    if i not in zBest_unique:
        zBest_unique.append(i)
        
zBest_unique.sort()

# %%
# Define H(z) based on cosmology at start of notebook:

hubble_z_inverse_c = lambda z: c/(np.sqrt((hubble_0**2)*(Omega_m*(1 + z)**3 + Omega_k*(1 + z)**2 + Omega_L)))

# %%
# Define chi_z_func - returns tuple with first element value and second element error for integral

chi_z_func = lambda z: scipy.integrate.quad(hubble_z_inverse_c, 0, z)
chi_z_func(.1)
# Out:
# (432.42751124745047, 4.8009097946827335e-12)

# %%
# Make a array of \chi(z) for interpolation 

chi_z_unique = []
for z in zBest_unique:
    chi_z_unique.append(chi_z_func(z)[0])

print("Redshift: " + str(zBest_unique[22]) + "      " + "Comoving Distance: " + str(chi_z_unique[22]))
# Out:
# Redshift: 0.101      Comoving Distance: 436.64473205282513

# %%
chi_z_func(1)
# Out:
# (3398.5621187715333, 3.773161914879012e-11)

# %% [markdown]
# ***

# %% [markdown]
# ### $z(\chi)$
#
# z_chi_func(chi_input) - returns redshift for a particular comoving distance

# %%
# Interpolate to get z(\chi)

z_chi_func = InterpolatedUnivariateSpline(chi_z_unique, zBest_unique, k=3)
z_chi_func(chi_z_unique[22])
# Out:
# array(0.101)

# %%
# Plot data and interpolation function for comparison

plt.plot(chi_z_unique, zBest_unique, 'o')
plt.plot(chi_z_unique, z_chi_func(chi_z_unique), '--')
plt.title("Interpolation of z(chi[Mpc]) function")

plt.show()

# %%
print(chi_z_func(1))
print(chi_z_func(0))
print(z_chi_func(3398))
print(z_chi_func(.01))
# Out:
# (3398.5621187715333, 3.773161914879012e-11)
# (0.0, 0.0)
# 0.9997485462266347
# 2.2363191156393736e-06

# %% [markdown]
# ***

# %% [markdown]
# ### $dz /\ d\chi$
#
# z_chi_func_deriv(\chi)

# %%
z_chi_func_deriv = z_chi_func.derivative()
z_chi_func_deriv(chi_z_unique[22])
# Out:
# array(0.00023718)

# %%
# Plot to check by eye
# Chi plot gives: (.6-.2)/(2500-1000) = .00026 and interpolation graph gives: (1500, .00028). Check. 

plt.plot(chi_z_unique, z_chi_func_deriv(chi_z_unique), '-')
plt.title("Derivative of Interpolation of z(chi) function")

plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ### $P(k, z(\chi))$
#
# matter_power_spectrum(k, z)

# %% [markdown]
# ### Notes:
#
# - Matter power spectrum look fine when compared to CAMB notebook: https://camb.readthedocs.io/en/latest/CAMBdemo.html

# %%
# Need the redshift and kh to have the same number of points 
# so that 2d interpolate gets arrays of the same length later. 

#Now get matter power spectra at redshift 0 and 1.0
params = camb.CAMBparams()
params.set_cosmology(H0=hubble_0, ombh2=ombh2, omch2=omch2)
params.InitPower.set_params(ns=ns)

#Note non-linear corrections couples to smaller scales than you want
params.set_matter_power(redshifts=np.linspace(0.0, 1.0, num = 100), kmax=2.0)

#Linear spectra
params.NonLinear = model.NonLinear_none
results = camb.get_results(params)
kh, z, pk = results.get_matter_power_spectrum(minkh=1e-4, maxkh=1, npoints = 100)
# Out:
# Note: redshifts have been re-sorted (earliest first)

# %%
# plor the power spectrum for z=0 and z=1

plt.loglog(kh, pk[0,:], color='k', ls = "-")
plt.loglog(kh, pk[-1,:], color='b', ls = "--")
plt.xlabel('k/h Mpc');
plt.legend(['linear'], loc='lower left');
plt.title('Matter power at z=0 and z=1')
plt.show()

# %%
#Interpolate the matter power spectrum into a function with arguments k & z

matter_power_spectrum = interpolate.interp2d(kh, z, pk, kind='quintic')

# %%
# Plot the matter power spectrum from CAMB and the interpolation
plt.figure(figsize=(12, 8))
kh_list = np.logspace(-4.0, 0, num=100)
z_list = np.linspace(min(z), max(z), num=100)


plt.loglog(kh, pk[-1,:], color='#88b378', ls = "-", label="PK_1 CAMB", linewidth=4, alpha=.6)
plt.loglog(kh, pk[0,:], color='#856798', ls = "-", label="PK_0 CAMB", linewidth=4, alpha=.6)

plt.loglog(kh_list, matter_power_spectrum(kh_list, z_list)[-1,:], color='#4b5d16', ls = "--", label="PK_1 Interp")
plt.loglog(kh_list, matter_power_spectrum(kh_list, z_list)[0,:], color='#36013f', ls = "--", label="PK_0 Interp")

plt.xlabel('k/h Mpc')
#plt.xlim(11**-4, 2)
plt.legend(loc = "upper right")
plt.title("CAMB vs Interpolate power spectrums")
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# $w(\theta)^{gg}_{ur} = b_u b_r \; \int \; n_u(z) n_r(z) \; \frac{dz}{d\chi} \frac{dz}{d\chi} \; d\chi \; \int \frac{k}{2 \pi} \; P(k, z(\chi)) \; J_0(\chi k \theta) \;dk $

# %% [markdown]
# ### Notes:
#
# - Inputting k_max, and first theta and first chi values integrand_k does evaluate to what it should looking at the power_spectrum graph above. CHECK
# - Need to work on good cutoff for bessel, chose the argument cut-off by playing with BesselJ[0,x]*exp(x^2/a) in mathematica - need to do more rigorously

# %% [markdown]
# ### Questions/Notes (for Ross)
#
# - What should the k range be for integration? In theory 0 to inf but I used the same k range as I use for the power spectrum from CAMB, reasonable?
# - Histogram binning for z distribution doesnt seem to affect below results much so not going to worry about that for now
# - The integral over k seems OK from some basic checking outlined above, but results seem off by a factor of 100?

# %% [markdown]
# ***

# %% [markdown]
# ## Troubleshooting:

# %% [markdown]
# ### Normalized number densities check:

# %% [markdown]
# $ \int \; n_u(z) n_r(z) \; \frac{dz}{d\chi} \frac{dz}{d\chi} \; d\chi == 1$

# %%
z_min = Sne_z_all_bin_centers.min()
z_max = Sne_z_all_bin_centers.max()

chi_min = chi_z_func(z_min)[0]
chi_max = chi_z_func(z_max)[0]

print("z_min: ",  z_min)
print("z_max: ",  z_max)
print("chi_min: ",  chi_min)
print("chi_max: ",  chi_max)
# Out:
# z_min:  0.04788925000000001
# z_max:  0.9176807500000002
# chi_min:  209.71246227424191
# chi_max:  3188.502255551903

# %%
x_values = np.linspace(chi_min, chi_max, num=100000)

plt.figure(figsize=[16, 8])
plt.plot(x_values, (n_sne_interpolated(z_chi_func(x_values)) * z_chi_func_deriv(x_values)), label="Interpolation", c="#8c000f", alpha=.7, lw=2)
plt.xlabel("co-moving distance")
plt.ylabel("n(z) $dz/d\chi$")
plt.show()

# %%
def quad_one_dim(integrand, limit_min, limit_max):

    integral = scipy.integrate.quad(integrand, limit_min, limit_max, epsrel=10**-12, epsabs=10**-12, limit=5000)
    
    return integral

# %%
# n(z) integral over z
quad_one_dim((lambda z: n_sne_interpolated(z)), 0, 1)
# Out:
# (0.9957766778191214, 3.5937919307116317e-13)

# %%
# n(z) dz/dx integral over x
quad_one_dim((lambda x: n_sne_interpolated(z_chi_func(x)) * z_chi_func_deriv(x)), chi_min, chi_max)
# Out:
# (0.9957767416525357, 9.279092909349614e-13)

# %% [markdown]
# ***

# %% [markdown]
# ### P(k) variance check for smoothness and magnitude

# %% [markdown]
# $ \; \int \; \int \frac{k}{2 \pi} \; P(k, z(\chi)) \; J_0(\chi k \theta) \; dk \; d\chi $

# %%
def power_argument(theta, chi, k):

    argumentValue = (k/(2*np.pi)) * ((1.0/h)**3) * (matter_power_spectrum(k*h, z_chi_func(chi))[0]) * scipy.special.jv(0, k*theta*chi)

    return argumentValue

def power_spectrum_only(theta, chi, k):

    argumentValue = ((1.0/h)**3) * (matter_power_spectrum(k*h, z_chi_func(chi))[0])

    return argumentValue

def bessel_only(theta, chi, k):

    argumentValue = scipy.special.jv(0, k*theta*chi)

    return argumentValue

# %%
power_argument(.1, 1000.0, .01)
# Out:
# 54.13369192708871

# %%
k_values = np.logspace(-4, 0, 100)
chi_values = np.linspace(1, 5000, 100)
theta_values = np.logspace(-2, 1, 10)

# %%
# create the matrix of chi and k values for different thetas

parameters_for_thetas = dict()

for theta in theta_values:
    k_array = []
    for k in k_values:
        chi_array = []
        for chi in chi_values:
            value = bessel_only(theta, chi, k)
            chi_array.append(value)
        k_array.append(chi_array)
    parameters_for_thetas[theta] = k_array
    print(len(parameters_for_thetas)/len(theta_values))

#parameters_for_thetas
# Out:
# 0.16666666666666666
# 0.3333333333333333
# 0.5
# 0.6666666666666666
# 0.8333333333333334
# 1.0

# %%
chi_values_strings = ["%.2f" % chi_values[i] for i in range(0, len(chi_values), 10)]
k_values_strings = ["%.6f" % k_values[i] for i in range(0, len(k_values), 10)]
theta = theta_values[3]
print(theta)

plt.figure(figsize=[16, 14])
plt.imshow(parameters_for_thetas[theta], cmap='Blues')
plt.xticks(np.linspace(0, 100, 10), chi_values_strings)
plt.yticks(np.linspace(0, 100, 10), k_values_strings)

plt.xlabel("comoving distance (Mpc)")
plt.ylabel("k (1/Mpc)")
plt.title("power_argument for theta = .1")
plt.colorbar()
# Out:
# 0.630957344480193

# %%
chi_values_strings = ["%.2f" % chi_values[i] for i in range(0, len(chi_values), 10)]
k_values_strings = ["%.6f" % k_values[i] for i in range(0, len(k_values), 10)]

#plt.figure(figsize=[16, 14])
#plt.imshow(parameters_for_thetas[theta], cmap='Blues')
#plt.xticks(np.linspace(0, 100, 10), chi_values_strings)
#plt.yticks(np.linspace(0, 100, 10), k_values_strings)

#plt.xlabel("comoving distance (Mpc)")
#plt.ylabel("k (1/Mpc)")
#plt.title("power_argument for theta = .1")
#plt.colorbar()

fig, axs = plt.subplots(2, 5, figsize=(15, 6), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .5, wspace=.001)

axs = axs.ravel()

for i in range(len(theta_values)):
    thetas = list(parameters_for_thetas.keys())
    axs[i].imshow(parameters_for_thetas[thetas[i]], cmap='Blues')
    #axs[i].set_xticks(np.linspace(0, 100, 10), chi_values_strings)
    
    
#plt.xlabel("comoving distance (Mpc)")
#plt.ylabel("k (1/Mpc)")
#plt.title("power_argument for theta = .1")
#plt.colorbar()

# %%
def auto_corr_function(bias, theta, k_min, k_max, chi_min, chi_max):
    
    constant = (bias**2) * ((1.0/h)**3)
    
    chi_depend = lambda x: ((n_sne_interpolated(z_chi_func(x)))**2) * ((z_chi_func_deriv(x))**2)
    
    k_depend = lambda k: (k/(2*np.pi))
    
    integrand_full = lambda x, k:  (constant * k_depend(k) 
                                    * chi_depend(x)* matter_power_spectrum(k*h, z_chi_func(x))[0] * scipy.special.jv(0, k*theta*x)) 
    
    value = scipy.integrate.dblquad(integrand_full, k_min, k_max, lambda k: chi_min, lambda k: chi_max)
    
    return value

# %%
def Bessel_inegral(bias, theta, k_min, k_max, chi_min, chi_max):    
    Bessel = lambda x, k:  scipy.special.jv(0, k*theta*x)    
    value = scipy.integrate.dblquad(Bessel, k_min, k_max, lambda k: chi_min, lambda k: chi_max)
    return value


theta_values = np.logspace(-2, 1, 10)


bessel_Integral_func_values = []
for theta in theta_values:
    print(theta)
    value = Bessel_inegral(bias=1, theta=theta, k_min=.0001*h, k_max=1.0*h, chi_min=chi_min, chi_max=chi_max)
    print(value)
    bessel_Integral_func_values.append(value[0])
    
plt.figure(figsize=(12, 8))

plt.scatter(theta_values, bessel_Integral_func_values)
# Out:
# 0.01
# (299.88168425971253, 3.6957827992103023e-07)
# 0.021544346900318832
# (125.08747568379816, 6.58245568330832e-07)
# 0.046415888336127774
# (59.10696686628377, 6.611917919744509e-07)
# 0.1
# (27.124910926015623, 4.420971798617893e-07)
# 0.21544346900318834
# (12.428258216567903, 6.951290063150699e-07)
# 0.46415888336127775
# (5.655649742934225, 34.707991063216674)
# 1.0
# (2.4922675246070365, 13524.840751879874)
# 2.154434690031882
# (1.029189867705997, 269.26488060357985)
# 4.6415888336127775
# (0.3822670559251362, 1454.165040208854)
# 10.0
# (0.04514302117873037, 142.66673693131696)

# %%
def Bessel_inegral_2(bias, theta, k_min, k_max, chi_min, chi_max):    
    Bessel = lambda x, k:  ((n_sne_interpolated(z_chi_func(x)))**2) * ((z_chi_func_deriv(x))**2) * (bias**2) * ((1.0/h)**3) * (k/(2*np.pi)) * matter_power_spectrum(k*h, z_chi_func(x))[0] * scipy.special.jv(0, k*theta*x)    
    value = scipy.integrate.dblquad(Bessel, k_min, k_max, lambda k: chi_min, lambda k: chi_max)
    return value


theta_values = np.logspace(-2, 1, 6)


bessel_Integral_func_values = []
for theta in theta_values:
    print(theta)
    value = Bessel_inegral_2(bias=1, theta=theta, k_min=.0001*h, k_max=1.0*h, chi_min=chi_min, chi_max=chi_max)
    print(value)
    bessel_Integral_func_values.append(value[0])
    
plt.figure(figsize=(12, 8))

plt.scatter(theta_values, bessel_Integral_func_values)
# Out:
# 0.01
# (0.012281133290123135, 1.4889170401382748e-08)
# 0.039810717055349734
# (0.00053111855101327, 1.489018411294982e-08)
# 0.15848931924611134
# (-5.768933188220756e-05, 1.4890654790206195e-08)
# 0.630957344480193
# /Users/megantabbutt/Library/Python/3.7/lib/python/site-packages/scipy/integrate/quadpack.py:881: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   **opt)
# /Users/megantabbutt/Library/Python/3.7/lib/python/site-packages/scipy/integrate/quadpack.py:881: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   **opt)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-8871b0ee878b> in <module>
#      11 for theta in theta_values:
#      12     print(theta)
# ---> 13     value = Bessel_inegral_2(bias=1, theta=theta, k_min=.0001*h, k_max=1.0*h, chi_min=chi_min, chi_max=chi_max)
#      14     print(value)
#      15     bessel_Integral_func_values.append(value[0])
#
# <ipython-input-58-8871b0ee878b> in Bessel_inegral_2(bias, theta, k_min, k_max, chi_min, chi_max)
#       1 def Bessel_inegral_2(bias, theta, k_min, k_max, chi_min, chi_max):
#       2     Bessel = lambda x, k:  ((n_sne_interpolated(z_chi_func(x)))**2) * ((z_chi_func_deriv(x))**2) * (bias**2) * ((1.0/h)**3) * (k/(2*np.pi)) * matter_power_spectrum(k*h, z_chi_func(x))[0] * scipy.special.jv(0, k*theta*x)
# ----> 3     value = scipy.integrate.dblquad(Bessel, k_min, k_max, lambda k: chi_min, lambda k: chi_max)
#       4     return value
#       5
#
# ~/Library/Python/3.7/lib/python/site-packages/scipy/integrate/quadpack.py in dblquad(func, a, b, gfun, hfun, args, epsabs, epsrel)
#     600
#     601     return nquad(func, [temp_ranges, [a, b]], args=args,
# --> 602             opts={"epsabs": epsabs, "epsrel": epsrel})
#     603
#     604
#
# ~/Library/Python/3.7/lib/python/site-packages/scipy/integrate/quadpack.py in nquad(func, ranges, args, opts, full_output)
#     824     else:
#     825         opts = [opt if callable(opt) else _OptFunc(opt) for opt in opts]
# --> 826     return _NQuad(func, ranges, opts, full_output).integrate(*args)
#     827
#     828
#
# ~/Library/Python/3.7/lib/python/site-packages/scipy/integrate/quadpack.py in integrate(self, *args, **kwargs)
#     879             f = partial(self.integrate, depth=depth+1)
#     880         quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# --> 881                       **opt)
#     882         value = quad_r[0]
#     883         abserr = quad_r[1]
#
# ~/Library/Python/3.7/lib/python/site-packages/scipy/integrate/quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     350     if weight is None:
#     351         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 352                        points)
#     353     else:
#     354         if points is not None:
#
# ~/Library/Python/3.7/lib/python/site-packages/scipy/integrate/quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     461     if points is None:
#     462         if infbounds == 0:
# --> 463             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     464         else:
#     465             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# ~/Library/Python/3.7/lib/python/site-packages/scipy/integrate/quadpack.py in integrate(self, *args, **kwargs)
#     879             f = partial(self.integrate, depth=depth+1)
#     880         quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# --> 881                       **opt)
#     882         value = quad_r[0]
#     883         abserr = quad_r[1]
#
# ~/Library/Python/3.7/lib/python/site-packages/scipy/integrate/quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     350     if weight is None:
#     351         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 352                        points)
#     353     else:
#     354         if points is not None:
#
# ~/Library/Python/3.7/lib/python/site-packages/scipy/integrate/quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     461     if points is None:
#     462         if infbounds == 0:
# --> 463             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     464         else:
#     465             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# <ipython-input-58-8871b0ee878b> in <lambda>(x, k)
#       1 def Bessel_inegral_2(bias, theta, k_min, k_max, chi_min, chi_max):
# ----> 2     Bessel = lambda x, k:  ((n_sne_interpolated(z_chi_func(x)))**2) * ((z_chi_func_deriv(x))**2) * (bias**2) * ((1.0/h)**3) * (k/(2*np.pi)) * matter_power_spectrum(k*h, z_chi_func(x))[0] * scipy.special.jv(0, k*theta*x)
#       3     value = scipy.integrate.dblquad(Bessel, k_min, k_max, lambda k: chi_min, lambda k: chi_max)
#       4     return value
#       5
#
# ~/Library/Python/3.7/lib/python/site-packages/scipy/interpolate/polyint.py in __call__(self, x)
#      72         """
#      73         x, x_shape = self._prepare_x(x)
# ---> 74         y = self._evaluate(x)
#      75         return self._finish_y(y, x_shape)
#      76
#
# ~/Library/Python/3.7/lib/python/site-packages/scipy/interpolate/interpolate.py in _evaluate(self, x_new)
#     655         #    The behavior is set by the bounds_error variable.
#     656         x_new = asarray(x_new)
# --> 657         y_new = self._call(self, x_new)
#     658         if not self._extrapolate:
#     659             below_bounds, above_bounds = self._check_bounds(x_new)
#
# ~/Library/Python/3.7/lib/python/site-packages/scipy/interpolate/interpolate.py in _call_spline(self, x_new)
#     643
#     644     def _call_spline(self, x_new):
# --> 645         return self._spline(x_new)
#     646
#     647     def _call_nan_spline(self, x_new):
#
# ~/Library/Python/3.7/lib/python/site-packages/scipy/interpolate/_bsplines.py in __call__(self, x, nu, extrapolate)
#     337         out = np.empty((len(x), prod(self.c.shape[1:])), dtype=self.c.dtype)
#     338         self._ensure_c_contiguous()
# --> 339         self._evaluate(x, nu, extrapolate, out)
#     340         out = out.reshape(x_shape + self.c.shape[1:])
#     341         if self.axis != 0:
#
# ~/Library/Python/3.7/lib/python/site-packages/scipy/interpolate/_bsplines.py in _evaluate(self, xp, nu, extrapolate, out)
#     348     def _evaluate(self, xp, nu, extrapolate, out):
#     349         _bspl.evaluate_spline(self.t, self.c.reshape(self.c.shape[0], -1),
# --> 350                 self.k, xp, nu, extrapolate, out)
#     351
#     352     def _ensure_c_contiguous(self):
#
# KeyboardInterrupt:

# %%
r_PanSTARRS_Full = np.array(PanSTARRS_Data['r_PanSTARRS_Full'])
xi_PanSTARRS_Full = np.array(PanSTARRS_Data['xi_PanSTARRS_Full'])

plt.figure(figsize=(12, 8))

plt.plot(r_PanSTARRS_Full, xi_PanSTARRS_Full, color='#4b5d16', label="Data")
plt.plot(r_PanSTARRS_Full, -xi_PanSTARRS_Full, color='#4b5d16', ls=':')

plt.scatter(theta_values, bessel_Integral_func_values, color='#36013f', ls="--", label="Theory")

plt.xscale('log')
plt.yscale('log', nonposy='clip')
plt.xlabel(r'$\theta$ (degrees)')
plt.ylabel(r'w($\theta$)')
plt.legend(loc='upper right')
#plt.xlim([0.01,10])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-957679d46e49> in <module>
#       7 plt.plot(r_PanSTARRS_Full, -xi_PanSTARRS_Full, color='#4b5d16', ls=':')
#       8
# ----> 9 plt.scatter(theta_values, bessel_Integral_func_values, color='#36013f', ls="--", label="Theory")
#      10
#      11 plt.xscale('log')
#
# ~/Library/Python/3.7/lib/python/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
#    2815         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2816         None else {}), **kwargs)
#    2817     sci(__ret)
#    2818     return __ret
#
# ~/Library/Python/3.7/lib/python/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/Library/Python/3.7/lib/python/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# ~/Library/Python/3.7/lib/python/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4389         y = np.ma.ravel(y)
#    4390         if x.size != y.size:
# -> 4391             raise ValueError("x and y must be the same size")
#    4392
#    4393         if s is None:
#
# ValueError: x and y must be the same size

# %%
def besselJ0(arg):
    return scipy.special.jv(0, arg)


def powerIntegral(x, theta, k_min, k_max):
    
    #integrand = lambda k: (k/(2*np.pi)) * ((1.0/h)**3) * matter_power_spectrum(k*h, z_chi_func(x))[0] * besselJ0(k*theta*x)
    integrand = lambda k: (k/(2*np.pi)) * ((1.0/h)**3) * matter_power_spectrum(k*h, z_chi_func(x))[0]
    integralValue = scipy.integrate.quad(integrand, k_min, k_max, epsrel=10**-12, epsabs=10**-12, limit=5000)
    
    return integralValue[0]


def auto_corr_function_1(bias, theta, k_min, k_max, chi_min, chi_max):
    
    integrand = lambda x: (bias**2) * powerIntegral(x, theta, k_min, k_max) * ((n_sne_interpolated(z_chi_func(x)))**2) * ((z_chi_func_deriv(x))**2)
    CorrValue = scipy.integrate.quad(integrand, chi_min, chi_max, epsrel=10**-12, epsabs=10**-12, limit=5000)
    
    return CorrValue[0]

# %%
theta_values = np.logspace(-2, 1, 6)

#theta_values = [.1]

corr_func_values = []
for theta in theta_values:
    print(theta)
    value = auto_corr_function_1(bias=1, theta=theta, k_min=.0001*h, k_max=1.0*h, chi_min=chi_min, chi_max=chi_max)
    print(value)
    corr_func_values.append(value)
# Out:
# 0.01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-c23227e35528> in <module>
#       6 for theta in theta_values:
#       7     print(theta)
# ----> 8     value = auto_corr_function_1(bias=1, theta=theta, k_min=.0001*h, k_max=1.0*h, chi_min=chi_min, chi_max=chi_max)
#       9     print(value)
#      10     corr_func_values.append(value)
#
# <ipython-input-39-3a6414b8380c> in auto_corr_function_1(bias, theta, k_min, k_max, chi_min, chi_max)
#      16
#      17     integrand = lambda x: (bias**2) * powerIntegral(x, theta, k_min, k_max) * ((n_sne_interpolated(z_chi_func(x)))**2) * ((z_chi_func_deriv(x))**2)
# ---> 18     CorrValue = scipy.integrate.quad(integrand, chi_min, chi_max, epsrel=10**-12, epsabs=10**-12, limit=5000)
#      19
#      20     return CorrValue[0]
#
# ~/Library/Python/3.7/lib/python/site-packages/scipy/integrate/quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     350     if weight is None:
#     351         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 352                        points)
#     353     else:
#     354         if points is not None:
#
# ~/Library/Python/3.7/lib/python/site-packages/scipy/integrate/quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     461     if points is None:
#     462         if infbounds == 0:
# --> 463             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     464         else:
#     465             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# <ipython-input-39-3a6414b8380c> in <lambda>(x)
#      15 def auto_corr_function_1(bias, theta, k_min, k_max, chi_min, chi_max):
#      16
# ---> 17     integrand = lambda x: (bias**2) * powerIntegral(x, theta, k_min, k_max) * ((n_sne_interpolated(z_chi_func(x)))**2) * ((z_chi_func_deriv(x))**2)
#      18     CorrValue = scipy.integrate.quad(integrand, chi_min, chi_max, epsrel=10**-12, epsabs=10**-12, limit=5000)
#      19
#
# <ipython-input-39-3a6414b8380c> in powerIntegral(x, theta, k_min, k_max)
#       7     #integrand = lambda k: (k/(2*np.pi)) * ((1.0/h)**3) * matter_power_spectrum(k*h, z_chi_func(x))[0] * besselJ0(k*theta*x)
#       8     integrand = lambda k: (k/(2*np.pi)) * ((1.0/h)**3) * matter_power_spectrum(k*h, z_chi_func(x))[0]
# ----> 9     integralValue = scipy.integrate.quad(integrand, k_min, k_max, epsrel=10**-12, epsabs=10**-12, limit=5000)
#      10
#      11     return integralValue[0]
#
# ~/Library/Python/3.7/lib/python/site-packages/scipy/integrate/quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     350     if weight is None:
#     351         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 352                        points)
#     353     else:
#     354         if points is not None:
#
# ~/Library/Python/3.7/lib/python/site-packages/scipy/integrate/quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     461     if points is None:
#     462         if infbounds == 0:
# --> 463             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     464         else:
#     465             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# <ipython-input-39-3a6414b8380c> in <lambda>(k)
#       6
#       7     #integrand = lambda k: (k/(2*np.pi)) * ((1.0/h)**3) * matter_power_spectrum(k*h, z_chi_func(x))[0] * besselJ0(k*theta*x)
# ----> 8     integrand = lambda k: (k/(2*np.pi)) * ((1.0/h)**3) * matter_power_spectrum(k*h, z_chi_func(x))[0]
#       9     integralValue = scipy.integrate.quad(integrand, k_min, k_max, epsrel=10**-12, epsabs=10**-12, limit=5000)
#      10
#
# ~/Library/Python/3.7/lib/python/site-packages/scipy/interpolate/interpolate.py in __call__(self, x, y, dx, dy, assume_sorted)
#     289                                 (self.y_min, self.y_max)))
#     290
# --> 291         z = fitpack.bisplev(x, y, self.tck, dx, dy)
#     292         z = atleast_2d(z)
#     293         z = transpose(z)
#
# ~/Library/Python/3.7/lib/python/site-packages/scipy/interpolate/_fitpack_impl.py in bisplev(x, y, tck, dx, dy)
#    1056     if len(z[0]) > 1:
#    1057         return z[0]
# -> 1058     return z[0][0]
#    1059
#    1060
#
# KeyboardInterrupt:

# %%
def auto_corr_function(bias, theta, k_min, k_max, chi_min, chi_max):
    
    constant = (bias**2) * ((1.0/h)**3)
    
    chi_depend = lambda x: ((n_sne_interpolated(z_chi_func(x)))**2) * ((z_chi_func_deriv(x))**2)
    
    k_depend = lambda k: (k/(2*np.pi))
    
    integrand_full = lambda x, k:  (constant * k_depend(k) 
                                    * chi_depend(x)* matter_power_spectrum(k*h, z_chi_func(x))[0] * scipy.special.jv(0, k*theta*x)) 
    
    value = scipy.integrate.dblquad(integrand_full, k_min, k_max, lambda k: chi_min, lambda k: chi_max)
    
    return value

# %%
"""theta_values = np.logspace(-2, 1, 6)

theta_values = [.1]

corr_func_values_1 = []
for theta in theta_values:
    print(theta)
    value = auto_corr_function(bias=1, theta=theta, k_min=.0001*h, k_max=1.0*h, chi_min=chi_z_func(redshift_min)[0], 
                               chi_max=chi_z_func(redshift_max)[0])
    print(value)
    corr_func_values_1.append(value)
"""
# Out:
# 'theta_values = np.logspace(-2, 1, 6)\n\ntheta_values = [.1]\n\ncorr_func_values_1 = []\nfor theta in theta_values:\n    print(theta)\n    value = auto_corr_function(bias=1, theta=theta, k_min=.0001*h, k_max=1.0*h, chi_min=chi_z_func(redshift_min)[0], \n                               chi_max=chi_z_func(redshift_max)[0])\n    print(value)\n    corr_func_values_1.append(value)\n'

# %%
#corr_func_values_single = []
#for value in corr_func_values:
#    corr_func_values_single.append(value[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-99659e16dac3> in <module>
#       1 corr_func_values_single = []
#       2 for value in corr_func_values:
# ----> 3     corr_func_values_single.append(value[0])
#
# TypeError: 'float' object is not subscriptable

# %%
plt.figure(figsize=(12, 8))

plt.scatter(theta_values, corr_func_values)
#plt.yscale("log")
#plt.xscale("log")
#plt.xlabel("Theta")
#plt.ylabel("w(Theta)")

#plt.title("Theoretical auto correlation function vs theta")

# %%
r_PanSTARRS_Full = np.array(PanSTARRS_Data['r_PanSTARRS_Full'])
xi_PanSTARRS_Full = np.array(PanSTARRS_Data['xi_PanSTARRS_Full'])

plt.figure(figsize=(12, 8))

plt.plot(r_PanSTARRS_Full, xi_PanSTARRS_Full, color='#4b5d16', label="Data")
plt.plot(r_PanSTARRS_Full, -xi_PanSTARRS_Full, color='#4b5d16', ls=':')

plt.scatter(theta_values, corr_func_values, color='#36013f', ls="--", label="Theory")

plt.xscale('log')
plt.yscale('log', nonposy='clip')
plt.xlabel(r'$\theta$ (degrees)')
plt.ylabel(r'w($\theta$)')
plt.legend(loc='upper right')
#plt.xlim([0.01,10])

plt.show()

# %%
"""t5 = datetime.now()

theta_values = np.logspace(-2, 1, 8)

# Parallelizing using Pool.apply()

# Step 1: Init multiprocessing.Pool()
pool = mp.Pool(mp.cpu_count())

# Step 2: `pool.apply` the `howmany_within_range()`
corr_func_values = [pool.apply(auto_corr_function, args=(1, theta, .01, 1, chi_z_func(redshift_min)[0], 
                                                         chi_z_func(redshift_max)[0])) for theta in theta_values]

# Step 3: Don't forget to close
pool.close()    

print(corr_func_values)

t6 = datetime.now()"""
print()

# %%
"""theta_values = np.logspace(-2, 1, 100)

chi_min_data = chi_z_func(redshift_min)[0]
chi_max_data = chi_z_func(redshift_max)[0]
chi_values = np.linspace(chi_min_data, chi_max_data, 100)

#Taken from the power spectrum range:
k_min = .0001 * h
k_max = 1.0 * h

arg_cut = 10000.0

corr_func_values = []
for theta in theta_values:
    
    integral_k_chi_values = []
    for chi in chi_values:
        
        bessel_arg = lambda k: k*theta*z_chi_func(chi)
        bessel_0 = lambda k: scipy.special.jv(0, bessel_arg(k)) 
        integrad_k = lambda k: (k/(2*np.pi))*matter_power_spectrum(k/h, z_chi_func(chi))[0]*bessel_0(k)*np.exp((bessel_arg(k)**2)/(arg_cut**2))
        #integrad_k = lambda k: (k/(2*np.pi))*matter_power_spectrum(k/h, z_chi_func(chi))[0]
        
        integral_k_chi = scipy.integrate.quad(integrad_k, k_min, k_max)[0]
        integral_k_chi_values.append(integral_k_chi)

    power_integral_chi_func = interpolate.interp1d(integral_k_chi_values, chi_values, kind='cubic', fill_value="extrapolate")
    #print(power_integral_chi_func(theta))
    print(len(corr_func_values)/len(theta_values))

    
    integrand_chi = lambda x: ((n_sne_interpolated(z_chi_func(x)))**2) * ((z_chi_func_deriv(x))**2) * power_integral_chi_func(theta) * (bias_Sne**2)
    integral_chi = scipy.integrate.quad(integrand_chi, 0, chi_max_data)[0]
    
    #print(integral_chi)
    corr_func_values.append(integral_chi)
    
    #print(len(corr_func_values)/len(theta_values))
          
Correlation = power_integral_chi_func = interpolate.interp1d(corr_func_values, theta_values, kind='cubic', fill_value="extrapolate")"""
print()

# %%
"""def BesselJ0(k):
    bessel_J0 = lambda x: scipy.special.jv(0, k*theta*x)
    return bessel_J0
      
    
#Camb power spec in units Mpc^3/h need it independent of h 
def integral_PowerSpectrum_overK(k_min, k_max):
    
    integrad_k = lambda k, x: k/(2*np.pi) * h * matter_power_spectrum(k/h, z_chi_func(x))[0] * BesselJ0(k)
    integral_k = lambda x: scipy.integrate.quad(integrad_k(x), k_min, k_max, epsrel=10**-12, epsabs=10**-12, limit=5000)
    
    return integral_k[0]
    
    
def auto_corr_function(bias, theta, k_min, k_max, chi_min, chi_max):
    
    integrand_chi = lambda x: (bias**2) * ((n_sne_interpolated(z_chi_func(x)))**2) * ((z_chi_func_deriv(x))**2) * integral_PowerSpectrum_overK(k_min, k_max)(x)
    integral_chi = scipy.integrate.quad(integrand_chi, chi_min, chi_max)
    
    return integral_chi[0] """
print()

# %%
"""# BesselJ0(theta) returns a function dependent on k, x: BesselJ0(theta)(k, x)
def BesselJ0(theta):
    bessel_J0 = lambda k, x: scipy.special.jv(0, k*theta*x)
    return bessel_J0 

# integral_PowerSpectrum_overK(k_min, k_max) returns a function dependent on x only: integral_PowerSpectrum_overK(k_min, k_max)(x)
def integral_PowerSpectrum_overK(k_min, k_max):
    
    integrad_k = lambda k, x: k/(2*np.pi) * h * matter_power_spectrum(k/h, z_chi_func(x))[0] * BesselJ0(theta)(k, x)
    integral_k = lambda x: scipy.integrate.quad(integrad_k, k_min, k_max, epsrel=10**-12, epsabs=10**-12, limit=5000)
    
    return integral_k

integral_PowerSpectrum_overK(.1, 1)(1)"""
print()
